# %% [markdown]
# # Plotting example using PlotRecipes

# %%
using PlotRecipes

# %%
T = Integer
sups = Any[T]
sup = T
while sup != Any
    sup = supertype(sup)
    unshift!(sups,sup)
end

# %%
n = length(sups)
nodes, source, destiny = copy(sups), collect(1:n-1), collect(2:n)
function add_subs!(T, supidx)
    for sub in subtypes(T)
        push!(nodes, sub)
        subidx = length(nodes)
        push!(source, supidx)
        push!(destiny, subidx)
        add_subs!(sub, subidx)
    end
end
add_subs!(T, n)
names = map(string, nodes);

# %%
names
# Out:
# 19-element Array{String,1}:
#  "Any"
#  "Number"
#  "Real"
#  "Integer"
#  "BigInt"
#  "Bool"
#  "GeometryTypes.OffsetInteger"
#  "Signed"
#  "Int128"
#  "Int16"
#  "Int32"
#  "Int64"
#  "Int8"
#  "Unsigned"
#  "UInt128"
#  "UInt16"
#  "UInt32"
#  "UInt64"
#  "UInt8"

# %%
graphplot([1], [2])
# Out:
# WARNING: Array(::Type{T}, m::Int) where T is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] get_source_destiny_weight(::SparseMatrixCSC{Float64,Int64}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:43
#  [4] estimate_distance(::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:166
#  [5] #by_axis_local_stress_graph#6(::Array{Float64,1}, ::Int64, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64, ::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:101
#  [6] (::PlotRecipes.#kw##by_axis_local_stress_graph)(::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at ./<missing>:0
#  [7] macro expansion at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:269 [inlined]
#  [8] apply_recipe(::Dict{Symbol,Any}, ::PlotRecipes.GraphPlot) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:287
#  [9] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/pipeline.jl:81
#  [10] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/plot.jl:177
#  [11] #graphplot#29(::Array{Any,1}, ::Function, ::Array{Int64,1}, ::Vararg{Array{Int64,1},N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [12] graphplot(::Array{Int64,1}, ::Vararg{Array{Int64,1},N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [13] include_string(::String, ::String) at ./loading.jl:522
#  [14] include_string(::Module, ::String, ::String) at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:174
#  [15] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/mt752/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [16] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:496
#  [17] eventloop(::ZMQ.Socket) at /home/mt752/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [18] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[12], in expression starting on line 1
# WARNING: Array(::Type{T}, m::Int) where T is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] get_source_destiny_weight(::SparseMatrixCSC{Float64,Int64}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:44
#  [4] estimate_distance(::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:166
#  [5] #by_axis_local_stress_graph#6(::Array{Float64,1}, ::Int64, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64, ::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:101
#  [6] (::PlotRecipes.#kw##by_axis_local_stress_graph)(::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at ./<missing>:0
#  [7] macro expansion at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:269 [inlined]
#  [8] apply_recipe(::Dict{Symbol,Any}, ::PlotRecipes.GraphPlot) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:287
#  [9] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/pipeline.jl:81
#  [10] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/plot.jl:177
#  [11] #graphplot#29(::Array{Any,1}, ::Function, ::Array{Int64,1}, ::Vararg{Array{Int64,1},N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [12] graphplot(::Array{Int64,1}, ::Vararg{Array{Int64,1},N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [13] include_string(::String, ::String) at ./loading.jl:522
#  [14] include_string(::Module, ::String, ::String) at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:174
#  [15] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/mt752/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [16] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:496
#  [17] eventloop(::ZMQ.Socket) at /home/mt752/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [18] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[12], in expression starting on line 1
# WARNING: Array(::Type{T}, m::Int) where T is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Float64}, ::Int64) at ./deprecated.jl:57
#  [3] get_source_destiny_weight(::SparseMatrixCSC{Float64,Int64}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:45
#  [4] estimate_distance(::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:166
#  [5] #by_axis_local_stress_graph#6(::Array{Float64,1}, ::Int64, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64, ::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:101
#  [6] (::PlotRecipes.#kw##by_axis_local_stress_graph)(::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at ./<missing>:0
#  [7] macro expansion at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:269 [inlined]
#  [8] apply_recipe(::Dict{Symbol,Any}, ::PlotRecipes.GraphPlot) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:287
#  [9] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/pipeline.jl:81
#  [10] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/plot.jl:177
#  [11] #graphplot#29(::Array{Any,1}, ::Function, ::Array{Int64,1}, ::Vararg{Array{Int64,1},N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [12] graphplot(::Array{Int64,1}, ::Vararg{Array{Int64,1},N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [13] include_string(::String, ::String) at ./loading.jl:522
#  [14] include_string(::Module, ::String, ::String) at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:174
#  [15] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/mt752/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [16] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:496
#  [17] eventloop(::ZMQ.Socket) at /home/mt752/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [18] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[12], in expression starting on line 1
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2800)" points="
# 15.748,384.252 580.315,384.252 580.315,11.811 15.748,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2802">
#     <rect x="15" y="11" width="566" height="373"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   15.748,384.252 580.315,384.252
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   15.748,384.252 15.748,11.811
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#d968a2; stroke-width:1; stroke-opacity:1; fill:none" points="
#   499.663,331.046 485.169,326.068 470.717,320.791 456.307,315.214 441.939,309.337 427.613,303.161 413.329,296.684 399.087,289.909 384.888,282.833 370.73,275.458
#   356.614,267.783 342.54,259.808 328.509,251.534 314.519,242.96 300.571,234.086 286.666,224.913 272.802,215.439 258.981,205.667 245.201,195.594 231.464,185.222
#   217.768,174.55 204.115,163.578 190.504,152.307 176.934,140.736 163.407,128.866 149.921,116.695 136.478,104.225 123.077,91.4554 109.718,78.386 96.4004,65.0169
#
#   "/>
# <circle clip-path="url(#clip2802)" style="fill:#000000; stroke:none; fill-opacity:1" cx="499.663" cy="331.046" r="54"/>
# <circle clip-path="url(#clip2802)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="499.663" cy="331.046" r="54"/>
# <circle clip-path="url(#clip2802)" style="fill:#000000; stroke:none; fill-opacity:1" cx="96.4004" cy="65.0169" r="54"/>
# <circle clip-path="url(#clip2802)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="96.4004" cy="65.0169" r="54"/>
# </svg>

# %%
weights = linspace(1,2,length(source))
graphplot(source, destiny, weights,
    names = names, method = :tree,
    l = (2, cgrad()),  # apply the default color gradient to the line (line_z values taken from edge weights)
    m = [node==T ? :orange : :steelblue for node in nodes]     # node colors
)
# Out:
# WARNING: Array(::Type{T}, m::Int) where T is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] get_source_destiny_weight(::SparseMatrixCSC{Float64,Int64}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:43
#  [4] estimate_distance(::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:166
#  [5] #by_axis_local_stress_graph#6(::Array{Float64,1}, ::Int64, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64, ::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:101
#  [6] (::PlotRecipes.#kw##by_axis_local_stress_graph)(::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at ./<missing>:0
#  [7] #tree_graph#16(::Array{Float64,1}, ::Symbol, ::Float64, ::Void, ::Void, ::Int64, ::Bool, ::Array{Any,1}, ::PlotRecipes.#tree_graph, ::Array{Int64,1}, ::Array{Int64,1}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:220
#  [8] (::PlotRecipes.#kw##tree_graph)(::Array{Any,1}, ::PlotRecipes.#tree_graph, ::Array{Int64,1}, ::Array{Int64,1}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at ./<missing>:0
#  [9] macro expansion at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:269 [inlined]
#  [10] apply_recipe(::Dict{Symbol,Any}, ::PlotRecipes.GraphPlot) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:287
#  [11] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/pipeline.jl:81
#  [12] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/plot.jl:177
#  [13] (::RecipesBase.#kw##plot)(::Array{Any,1}, ::RecipesBase.#plot, ::PlotRecipes.GraphPlot) at ./<missing>:0
#  [14] #graphplot#29(::Array{Any,1}, ::Function, ::Array{Int64,1}, ::Vararg{Any,N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [15] (::PlotRecipes.#kw##graphplot)(::Array{Any,1}, ::PlotRecipes.#graphplot, ::Array{Int64,1}, ::Vararg{Any,N} where N) at ./<missing>:0
#  [16] include_string(::String, ::String) at ./loading.jl:522
#  [17] include_string(::Module, ::String, ::String) at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:174
#  [18] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/mt752/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [19] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:496
#  [20] eventloop(::ZMQ.Socket) at /home/mt752/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [21] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[9], in expression starting on line 2
# WARNING: Array(::Type{T}, m::Int) where T is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] get_source_destiny_weight(::SparseMatrixCSC{Float64,Int64}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:44
#  [4] estimate_distance(::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:166
#  [5] #by_axis_local_stress_graph#6(::Array{Float64,1}, ::Int64, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64, ::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:101
#  [6] (::PlotRecipes.#kw##by_axis_local_stress_graph)(::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at ./<missing>:0
#  [7] #tree_graph#16(::Array{Float64,1}, ::Symbol, ::Float64, ::Void, ::Void, ::Int64, ::Bool, ::Array{Any,1}, ::PlotRecipes.#tree_graph, ::Array{Int64,1}, ::Array{Int64,1}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:220
#  [8] (::PlotRecipes.#kw##tree_graph)(::Array{Any,1}, ::PlotRecipes.#tree_graph, ::Array{Int64,1}, ::Array{Int64,1}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at ./<missing>:0
#  [9] macro expansion at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:269 [inlined]
#  [10] apply_recipe(::Dict{Symbol,Any}, ::PlotRecipes.GraphPlot) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:287
#  [11] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/pipeline.jl:81
#  [12] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/plot.jl:177
#  [13] (::RecipesBase.#kw##plot)(::Array{Any,1}, ::RecipesBase.#plot, ::PlotRecipes.GraphPlot) at ./<missing>:0
#  [14] #graphplot#29(::Array{Any,1}, ::Function, ::Array{Int64,1}, ::Vararg{Any,N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [15] (::PlotRecipes.#kw##graphplot)(::Array{Any,1}, ::PlotRecipes.#graphplot, ::Array{Int64,1}, ::Vararg{Any,N} where N) at ./<missing>:0
#  [16] include_string(::String, ::String) at ./loading.jl:522
#  [17] include_string(::Module, ::String, ::String) at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:174
#  [18] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/mt752/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [19] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:496
#  [20] eventloop(::ZMQ.Socket) at /home/mt752/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [21] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[9], in expression starting on line 2
# WARNING: Array(::Type{T}, m::Int) where T is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Float64}, ::Int64) at ./deprecated.jl:57
#  [3] get_source_destiny_weight(::SparseMatrixCSC{Float64,Int64}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:45
#  [4] estimate_distance(::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:166
#  [5] #by_axis_local_stress_graph#6(::Array{Float64,1}, ::Int64, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64, ::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:101
#  [6] (::PlotRecipes.#kw##by_axis_local_stress_graph)(::Array{Any,1}, ::PlotRecipes.#by_axis_local_stress_graph, ::Array{Float64,2}) at ./<missing>:0
#  [7] #tree_graph#16(::Array{Float64,1}, ::Symbol, ::Float64, ::Void, ::Void, ::Int64, ::Bool, ::Array{Any,1}, ::PlotRecipes.#tree_graph, ::Array{Int64,1}, ::Array{Int64,1}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at /home/mt752/.julia/v0.6/PlotRecipes/src/graph_layouts.jl:220
#  [8] (::PlotRecipes.#kw##tree_graph)(::Array{Any,1}, ::PlotRecipes.#tree_graph, ::Array{Int64,1}, ::Array{Int64,1}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at ./<missing>:0
#  [9] macro expansion at /home/mt752/.julia/v0.6/PlotRecipes/src/graphs.jl:269 [inlined]
#  [10] apply_recipe(::Dict{Symbol,Any}, ::PlotRecipes.GraphPlot) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:287
#  [11] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/pipeline.jl:81
#  [12] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{PlotRecipes.GraphPlot}) at /home/mt752/.julia/v0.6/Plots/src/plot.jl:177
#  [13] (::RecipesBase.#kw##plot)(::Array{Any,1}, ::RecipesBase.#plot, ::PlotRecipes.GraphPlot) at ./<missing>:0
#  [14] #graphplot#29(::Array{Any,1}, ::Function, ::Array{Int64,1}, ::Vararg{Any,N} where N) at /home/mt752/.julia/v0.6/RecipesBase/src/RecipesBase.jl:363
#  [15] (::PlotRecipes.#kw##graphplot)(::Array{Any,1}, ::PlotRecipes.#graphplot, ::Array{Int64,1}, ::Vararg{Any,N} where N) at ./<missing>:0
#  [16] include_string(::String, ::String) at ./loading.jl:522
#  [17] include_string(::Module, ::String, ::String) at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:174
#  [18] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/mt752/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [19] (::Compat.#inner#16{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/mt752/.julia/v0.6/Compat/src/Compat.jl:496
#  [20] eventloop(::ZMQ.Socket) at /home/mt752/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [21] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[9], in expression starting on line 2
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2600)" points="
# 15.748,384.252 580.315,384.252 580.315,11.811 15.748,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2602">
#     <rect x="15" y="11" width="566" height="373"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   15.748,384.252 580.315,384.252
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   15.748,384.252 15.748,11.811
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#0a0622; stroke-width:2; stroke-opacity:1; fill:none" points="
#   377.333,65.0169 377.174,66.5737
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#1d0b44; stroke-width:2; stroke-opacity:1; fill:none" points="
#   377.174,66.5737 376.712,68.0939
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#370961; stroke-width:2; stroke-opacity:1; fill:none" points="
#   376.712,68.0939 375.969,69.58
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#510d6c; stroke-width:2; stroke-opacity:1; fill:none" points="
#   375.969,69.58 374.968,71.0348
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#68166e; stroke-width:2; stroke-opacity:1; fill:none" points="
#   374.968,71.0348 373.731,72.461
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#801f6b; stroke-width:2; stroke-opacity:1; fill:none" points="
#   373.731,72.461 372.281,73.8613
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#982765; stroke-width:2; stroke-opacity:1; fill:none" points="
#   372.281,73.8613 370.64,75.2385
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#af305b; stroke-width:2; stroke-opacity:1; fill:none" points="
#   370.64,75.2385 368.83,76.5953
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#c53d4d; stroke-width:2; stroke-opacity:1; fill:none" points="
#   368.83,76.5953 366.875,77.9343
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#d84c3d; stroke-width:2; stroke-opacity:1; fill:none" points="
#   366.875,77.9343 364.796,79.2585
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#e8612b; stroke-width:2; stroke-opacity:1; fill:none" points="
#   364.796,79.2585 362.616,80.5703
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#f37917; stroke-width:2; stroke-opacity:1; fill:none" points="
#   362.616,80.5703 360.357,81.8726
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke: